# %% [markdown]
# # Combined Cycle Power Plant
#
# ## Shifa Shaikh
# ### EE257
# #### HW#1
#
#
#
# ## Note: Many classmates asked for help in the HW because I took EE258 and I know a bit more than them. I am not sure if they copied my HW. I advised them to use it as a reference but not to copy-paste it.

# %% [markdown]
# # Problem: 4

# %% [markdown]
# # a) Explain the dataset
#
# The dataset was recorded in the years 2006 to 2011. It has approximately 9500 datapoints. The plant recorded Temperature (T), Ambient Pressure (AP), Relative Humidity (RH) and Exhaust Vaccum (V) hourly. The data is format is available in both .ods and .xlsx formats.

# %%
# Import the library

import pandas as pd
import matplotlib.pyplot as plt

# %%
# Download the data and read the sheets using pandas library

plant1 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Machine Learning/HW#1/Folds5x2_pp.xlsx", sheet_name=0)
plant2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Machine Learning/HW#1/Folds5x2_pp.xlsx", sheet_name=1)
plant3 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Machine Learning/HW#1/Folds5x2_pp.xlsx", sheet_name=2)
plant4 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Machine Learning/HW#1/Folds5x2_pp.xlsx", sheet_name=3)
plant5 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/Machine Learning/HW#1/Folds5x2_pp.xlsx", sheet_name=4)

# %%
# Checking the first five rows in the dataset

print("Sheet-1")
plant1.head()
# Out:
# Sheet-1
#       AT      V       AP     RH      PE
# 0  14.96  41.76  1024.07  73.17  463.26
# 1  25.18  62.96  1020.04  59.08  444.37
# 2   5.11  39.40  1012.16  92.14  488.56
# 3  20.86  57.32  1010.24  76.64  446.48
# 4  10.82  37.50  1009.23  96.62  473.90

# %%
print("Sheet-2")
plant2.head()
# Out:
# Sheet-2
#       AT      V       AP     RH      PE
# 0   9.59  38.56  1017.01  60.10  481.30
# 1  12.04  42.34  1019.72  94.67  465.36
# 2  13.87  45.08  1024.42  81.69  465.48
# 3  13.72  54.30  1017.89  79.08  467.05
# 4  15.14  49.64  1023.78  75.00  463.58

# %%
print("Sheet-3")
plant3.head()
# Out:
# Sheet-3
#       AT      V       AP     RH      PE
# 0   9.44  40.00  1015.62  81.16  471.32
# 1  23.49  49.30  1003.35  77.96  442.76
# 2   4.99  39.04  1020.45  78.89  472.52
# 3  18.24  58.46  1017.38  86.92  449.63
# 4  27.49  63.78  1015.43  47.45  445.66

# %%
print("Sheet-4")
plant4.head()
# Out:
# Sheet-4
#       AT      V       AP     RH      PE
# 0  23.25  71.29  1008.05  71.36  442.21
# 1  13.87  42.99  1007.45  81.52  471.12
# 2  16.91  43.96  1013.32  79.87  465.86
# 3  10.09  37.14  1012.99  72.59  473.66
# 4  12.72  40.60  1013.45  86.16  471.23

# %%
print("Sheet-5")
plant5.head()
# Out:
# Sheet-5
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %%
# Sheet 1
print("The description of Sheet-1")
plant1.describe()
# Out:
# The description of Sheet-1
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
print("The description of Sheet-2")
plant2.describe()
# Out:
# The description of Sheet-2
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
print("The description of Sheet-3")
plant3.describe()
# Out:
# The description of Sheet-3
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
print("The description of Sheet-4")
plant4.describe()
# Out:
# The description of Sheet-4
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %%
print("The description of Sheet-5")
plant5.describe()
# Out:
# The description of Sheet-5
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %% [markdown]
# All the sheets have same datapoints so we can use any one of the sheets for further consideration. We will consider Sheet-1 (Plant1)

# %%
plant1['AP']
# Out:
# 0       1024.07
# 1       1020.04
# 2       1012.16
# 3       1010.24
# 4       1009.23
#          ...
# 9563    1014.01
# 9564    1023.67
# 9565    1012.92
# 9566    1013.86
# 9567    1017.23
# Name: AP, Length: 9568, dtype: float64

# %%
# Drop if empty

clean_plant1 = plant1.dropna()

# %%
clean_plant1.describe()
# Out:
#                 AT            V           AP           RH           PE
# count  9568.000000  9568.000000  9568.000000  9568.000000  9568.000000
# mean     19.651231    54.305804  1013.259078    73.308978   454.365009
# std       7.452473    12.707893     5.938784    14.600269    17.066995
# min       1.810000    25.360000   992.890000    25.560000   420.260000
# 25%      13.510000    41.740000  1009.100000    63.327500   439.750000
# 50%      20.345000    52.080000  1012.940000    74.975000   451.550000
# 75%      25.720000    66.540000  1017.260000    84.830000   468.430000
# max      37.110000    81.560000  1033.300000   100.160000   495.760000

# %% [markdown]
# The dataset did not have any blank datapoints.

# %%
clean_plant1.hist(bins=20, figsize=(15,15), color="m")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff52671e6d8>,
# ...
#       dtype=object)

# %%
clean_plant1.boxplot(column=["AT"], fontsize=15, figsize=(7,7))

# %%
clean_plant1.boxplot(column=["V"], fontsize=15, figsize=(7,7))

# %%
clean_plant1.boxplot(column=["AP"], fontsize=15, figsize=(7,7))

# %%
clean_plant1.boxplot(column=["RH"], fontsize=15, figsize=(7,7))

# %%
clean_plant1.boxplot(column=["PE"], fontsize=15, figsize=(7,7))

# %%
clean_plant1.plot(kind = "scatter", x="AT", y = "AP", figsize=(10,10), color="c")

# %%
clean_plant1.plot(kind = "scatter", x="RH", y = "V", figsize=(10,10), color="lightcoral")

# %%
clean_plant1.plot(kind = "scatter", x="V", y = "PE", figsize=(10,10), color="chartreuse")

# %%
correlation_plant = clean_plant1.corr()
correlation_plant["AT"].sort_values()
# Out:
# PE   -0.948128
# RH   -0.542535
# AP   -0.507549
# V     0.844107
# AT    1.000000
# Name: AT, dtype: float64

# %%
pd.plotting.scatter_matrix(clean_plant1, figsize=(20,20), color ="tomato")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7ff51a68c828>,
# ...
#       dtype=object)

# %% [markdown]
# # Problem: 5

# %% [markdown]
# # *AI, Philosophy, Ethics and Impact*
#
# Artificial Intelligence was developed to make the machines understand the tasks and not do sequential tasks blindly. The controversy that AI will reduce the human involvement is wrong according to me. Because as the technology advances there are more and more white-collar jobs produced. The need of human resource to maintain, upgrade and develop also arises. Although, people will relay on machines for each and every task, there will be need of humans to supervise those machines. IBM Watson is using it's intellect to diagnose diseases like cancer, doctors might be still needed in order to verify those results. Accuracy of such operations is still the highest priority but human involvement can not be ignored. Same goes for Sophia and her family. They are developed to study various coginitve computing capabilities. To enhance these capabilities, human mind will be required. Humans will be focussing on more complex future tasks than to solve the problems which has already been solved by humans. To switch this idea to the machines will only create better opportunities in the world for humans and will motivate them to learn and improve themselve
